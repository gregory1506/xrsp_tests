# %%
import urllib.request

# %%
url = 'http://landsat-pds.s3.amazonaws.com/c1/L8/042/034/LC08_L1TP_042034_20170616_20170629_01_T1/'
redband = 'LC08_L1TP_042034_20170616_20170629_01_T1_B{}.TIF'.format(4)
nirband = 'LC08_L1TP_042034_20170616_20170629_01_T1_B{}.TIF'.format(5)

# %%
urllib.request.urlretrieve(url+redband, "C:\\Users\\gr3g\\Greg_Projects\\xarray-spatial\\"+redband)
# Out:
# ('C:\\Users\\gr3g\\Greg_Projects\\xarray-spatial\\LC08_L1TP_042034_20170616_20170629_01_T1_B4.TIF',
#  <http.client.HTTPMessage at 0x1ea7302a5e0>)

# %%
urllib.request.urlretrieve(url+nirband, "C:\\Users\\gr3g\\Greg_Projects\\xarray-spatial\\"+nirband)
# Out:
# ('C:\\Users\\gr3g\\Greg_Projects\\xarray-spatial\\LC08_L1TP_042034_20170616_20170629_01_T1_B5.TIF',
#  <http.client.HTTPMessage at 0x1ea73a26a30>)

# %%
import xarray as xr
from xrspatial import ndvi

# %%
red = xr.open_rasterio("LC08_L1TP_042034_20170616_20170629_01_T1_B4.TIF")
red
# Out:
# <xarray.DataArray (band: 1, y: 7951, x: 7821)>
# [62184771 values with dtype=uint16]
# Coordinates:
#   * band     (band) int32 1
#   * y        (y) float64 4.268e+06 4.268e+06 4.268e+06 ... 4.03e+06 4.03e+06
#   * x        (x) float64 2.043e+05 2.043e+05 2.044e+05 ... 4.389e+05 4.389e+05
# Attributes:
#     transform:      (30.0, 0.0, 204285.0, 0.0, -30.0, 4268115.0)
#     crs:            +init=epsg:32611
#     res:            (30.0, 30.0)
#     is_tiled:       1
#     nodatavals:     (nan,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     AREA_OR_POINT:  Point

# %%
red.plot()
# Out:
# C:\Users\gr3g\anaconda3\envs\xrsp\lib\site-packages\ipykernel\pylab\config.py:70: DeprecationWarning: InlineBackend._figure_formats_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_formats_changed(self, name, old, new):
# Error in callback <function flush_figures at 0x000001EA7F8C7700> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\envs\xrsp\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~\anaconda3\envs\xrsp\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#    2047         else:
# -> 2048             renderer.draw_quad_mesh(
#    2049                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#
# ...
